# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('ign.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
# ...

# %% [markdown]
# # Compute the Mean and Standard Deviation review  Score of games in three faviour Genere

# %% [markdown]
# # Mean of Score with respect to Attribute Genre Containg value Action

# %% [markdown]
# # First Method

# %%
Action_mean=df.groupby(df['genre']=="Action").score.mean()

# %%
print(Action_mean)
# Out:
# genre
# False    7.033369
# True     6.626679
# Name: score, dtype: float64

# %% [markdown]
# # Second Method

# %%
grp=df.groupby('genre')

# %%
Action=grp.get_group('Action')

# %%
mean_Action=Action['score'].agg(np.mean)

# %%
print(mean_Action)
# Out:
# 6.626678957071378

# %% [markdown]
# # Mean of Score with respect to Attribute Genre Containg value Sports

# %% [markdown]
# # First Method

# %%
Sports_mean=df.groupby(df['genre']=="Sports").score.mean()

# %%
print(Sports_mean)
# Out:
# genre
# False    6.941888
# True     7.025209
# Name: score, dtype: float64

# %% [markdown]
# # Second Method

# %%
grp=df.groupby('genre')

# %%
Sports=grp.get_group('Sports')

# %%
mean_Sports=Sports['score'].agg(np.mean)

# %%
print(mean_Sports)
# Out:
# 7.025208768267201

# %% [markdown]
# # Mean of Score with respect to Attribute Genre Containg value RPG

# %% [markdown]
# # First Method

# %%
RPG_mean=df.groupby(df['genre']=="RPG").score.mean()

# %%
RPG_mean
# Out:
# genre
# False    6.915971
# True     7.571429
# Name: score, dtype: float64

# %% [markdown]
# # Second Method

# %%
grp=df.groupby('genre')

# %%
RPG=grp.get_group('RPG')

# %%
mean_RPG=RPG['score'].agg(np.mean)

# %%
print(mean_RPG)
# Out:
# 7.571428571428587

# %% [markdown]
# # Standard Deviation of Score with respect to Attribute Genre Containg value Action

# %% [markdown]
# # First Method

# %%
Action_std=df.groupby(df['genre']=="Action").score.std()

# %%
Action_std
# Out:
# genre
# False    1.707243
# True     1.690888
# Name: score, dtype: float64

# %% [markdown]
# # Second Method

# %%
grp=df.groupby('genre')

# %%
Action=grp.get_group('Action')

# %%
Std_Action=Action['score'].agg(np.std)

# %%
print(Std_Action)
# Out:
# 1.6908876387142766

# %% [markdown]
# # Standard Deviation of Score with respect to Attribute Genre Containg value Sports

# %% [markdown]
# # First Method

# %%
Sports_std=df.groupby(df['genre']=="Sports").score.std()

# %%
Sports_std
# Out:
# genre
# False    1.696215
# True     1.840336
# Name: score, dtype: float64

# %% [markdown]
# # Second Method

# %%
grp=df.groupby('genre')

# %%
Sport=grp.get_group('Sports')

# %%
std_Sports=Sports['score'].agg(np.std)

# %%
print(std_Sports)
# Out:
# 1.8403360483929199

# %% [markdown]
# # Standard Deviation of Score with respect to Attribute Genre Containg value RPG

# %% [markdown]
# # First Method

# %%
RPG_std=df.groupby(df['genre']=="RPG").score.std()

# %%
RPG_std
# Out:
# genre
# False    1.720109
# True     1.416941
# Name: score, dtype: float64

# %% [markdown]
# # Second Method

# %%
grp=df.groupby('genre')

# %%
RPG=grp.get_group('RPG')

# %%
std_RPG=RPG['score'].agg(np.std)

# %%
print(std_RPG)
# Out:
# 1.4169411298550711

# %% [markdown]
# # B: Z-Score Computation relative to the favourite game genre

# %% [markdown]
# # B: Z-Score Computation relative to the Acton game genre

# %%
Z_Action=df['score']-mean_Action/Std_Action

# %%
print(Z_Action)
# Out:
# 0        5.080947
# 1        5.080947
# 2        4.580947
# 3        4.580947
# 4        4.580947
#            ...
# 18620    3.680947
# 18621    5.080947
# 18622    1.880947
# 18623    6.080947
# 18624    6.080947
# Name: score, Length: 18625, dtype: float64

# %% [markdown]
# # Z-Score Computation relative to the Sports game genre

# %%
Z_Sports=df['score']-mean_Sports/std_Sports

# %%
print(Z_Sports)
# Out:
# 0        5.182649
# 1        5.182649
# 2        4.682649
# 3        4.682649
# 4        4.682649
#            ...
# 18620    3.782649
# 18621    5.182649
# 18622    1.982649
# 18623    6.182649
# 18624    6.182649
# Name: score, Length: 18625, dtype: float64

# %% [markdown]
# # Z-Score Computation relative to the RPG game genre

# %%
Z_RPG=df['score']-mean_RPG/std_RPG

# %%
print(Z_RPG)
# Out:
# 0        3.656497
# 1        3.656497
# 2        3.156497
# 3        3.156497
# 4        3.156497
#            ...
# 18620    2.256497
# 18621    3.656497
# 18622    0.456497
# 18623    4.656497
# 18624    4.656497
# Name: score, Length: 18625, dtype: float64

# %% [markdown]
# # Superior Game with respect three faviourate Game

# %% [markdown]
# Sports game is the superior games with the highest z_score. It has high z-score becauase of high mean and standard Deviation.

# %% [markdown]
# # C: Histogram

# %% [markdown]
# # Histogram of Action Genre

# %%
x=list(df['score'].groupby(df['genre']=='Action'))[1][1]

# %%
x=x
num_bins = 10
n, bins, patches = plt.hist(x, num_bins, width=1)
plt.show()

# %%
y=list(df['score'].groupby(df['genre']=='Sports'))[0][1]

# %%
x=y
num_bins = 10
n, bins, patches = plt.hist(x, num_bins, width=1)
plt.show()

# %%
z=list(df['score'].groupby(df['genre']=='RPG'))[1][1]

# %%
x=z
num_bins = 10
n, bins, patches = plt.hist(x, num_bins, width=1)
plt.show()

# %% [markdown]
# # D:- Pie Plot Score Phrases

# %%
score_phrase = df[df['release_year'] ==1996]['score_phrase']
temp = score_phrase.value_counts()
print("Number of games reviewed in 199:",df[df['release_year']==1996]['title'].count())
score_phrase_top10 = temp.head(10)
score_phrase_top10['remaining {0} items'.format(len(temp)-10)] = sum(temp[10:])
score_phrase_top10.plot(kind='pie')
plt.title('Most common genres in 1996')
plt.pie(score_phrase_top10,autopct='%1.0f%%')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()
# Out:
# Number of games reviewed in 199: 149

# %%
score_phrase = df[df['release_year'] ==2000]['score_phrase']
temp = score_phrase.value_counts()
print("Number of games reviewed in 2000:",df[df['release_year']==2000]['title'].count())
score_phrase_top10 = temp.head(10)
score_phrase_top10['remaining {0} items'.format(len(temp)-10)] = sum(temp[10:])
score_phrase_top10.plot(kind='pie')
plt.title('Most common genres in 2000')
plt.pie(score_phrase_top10,autopct='%1.0f%%')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()
# Out:
# Number of games reviewed in 2000: 1045

# %%
score_phrase = df[df['release_year'] ==2001]['score_phrase']
temp = score_phrase.value_counts()
print("Number of games reviewed in 2001:",df[df['release_year']==2001]['title'].count())
score_phrase_top10 = temp.head(10)
score_phrase_top10['remaining {0} items'.format(len(temp)-10)] = sum(temp[10:])
score_phrase_top10.plot(kind='pie')
plt.title('Most common genres in 2001')
plt.pie(score_phrase_top10,autopct='%1.0f%%')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()
# Out:
# Number of games reviewed in 2001: 688

# %%
score_phrase = df[df['release_year'] ==2005]['score_phrase']
temp = score_phrase.value_counts()
print("Number of games reviewed in 2005:",df[df['release_year']==2005]['title'].count())
score_phrase_top10 = temp.head(10)
score_phrase_top10['remaining {0} items'.format(len(temp)-10)] = sum(temp[10:])
score_phrase_top10.plot(kind='pie')
plt.title('Most common genres in 2005')
plt.pie(score_phrase_top10,autopct='%1.0f%%')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()
# Out:
# Number of games reviewed in 2005: 1088

# %%
score_phrase = df[df['release_year'] ==2006]['score_phrase']
temp = score_phrase.value_counts()
print("Number of games reviewed in 2006:",df[df['release_year']==2006]['title'].count())
score_phrase_top10 = temp.head(10)
score_phrase_top10['remaining {0} items'.format(len(temp)-10)] = sum(temp[10:])
score_phrase_top10.plot(kind='pie')
plt.title('Most common genres in 2006')
plt.pie(score_phrase_top10,autopct='%1.0f%%')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()
# Out:
# Number of games reviewed in 2006: 1208

# %%
score_phrase = df[df['release_year'] ==2010]['score_phrase']
temp = score_phrase.value_counts()
print("Number of games reviewed in 2010:",df[df['release_year']==2010]['title'].count())
score_phrase_top10 = temp.head(10)
score_phrase_top10['remaining {0} items'.format(len(temp)-10)] = sum(temp[10:])
score_phrase_top10.plot(kind='pie')
plt.title('Most common genres in 2010')
plt.pie(score_phrase_top10,autopct='%1.0f%%')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()
# Out:
# Number of games reviewed in 2010: 1363

# %%
score_phrase = df[df['release_year'] ==2011]['score_phrase']
temp = score_phrase.value_counts()
print("Number of games reviewed in 2011:",df[df['release_year']==2011]['title'].count())
score_phrase_top10 = temp.head(10)
score_phrase_top10['remaining {0} items'.format(len(temp)-10)] = sum(temp[10:])
score_phrase_top10.plot(kind='pie')
plt.title('Most common genres in 2011')
plt.pie(score_phrase_top10,autopct='%1.0f%%')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()
# Out:
# Number of games reviewed in 2011: 1073

# %%
score_phrase = df[df['release_year'] ==2015]['score_phrase']
temp = score_phrase.value_counts()
print("Number of games reviewed in 2015:",df[df['release_year']==2015]['title'].count())
score_phrase_top10 = temp.head(10)
score_phrase_top10['remaining {0} items'.format(len(temp)-10)] = sum(temp[10:])
score_phrase_top10.plot(kind='pie')
plt.title('Most common genres in 2015')
plt.pie(score_phrase_top10,autopct='%1.0f%%')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()
# Out:
# Number of games reviewed in 2015: 365

# %% [markdown]
# The release year 2010 has the high score phrases and almost 1363 movies were released in this year and have segnificant imptant beside others.

# %% [markdown]
# # E: Construct Bar Plot of the Quantity of the Editor Choice award given  to Games on your faviourate plateform by year

# %%
df.editors_choice=df.editors_choice.replace('Y',1)
df.editors_choice=df.editors_choice.replace('N',0)
df.head()
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
# ...

# %%
df3=df[['platform','release_year','editors_choice']]
df3=df3.groupby(['platform','release_year']).agg(['count','sum'])
df3.columns=df3.columns.droplevel()
df3.columns=['nGamesReleased','nAwardsRecvd']
df3=df3.sort_values(by=['nAwardsRecvd'],ascending=False)
exceptions=df3[df3.nAwardsRecvd==0].sort_values('nGamesReleased',ascending=False)[:3]
df3=df3[df3.nAwardsRecvd!=0]
df3['Award_Ratio']=df3.nAwardsRecvd/df3.nGamesReleased
exceptions=exceptions.append(df3[df3.nGamesReleased>=10][df3.Award_Ratio<0.10])
exceptions=exceptions.sort_values("nGamesReleased",ascending=False)
exceptions.to_csv("task2exceptions.csv")
df3.to_csv("task2.csv")
df3[(df3.nGamesReleased>10) & (df3.Award_Ratio>0.10)].head(20)
# Out:
# C:\Users\zubai\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# C:\Users\zubai\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#                             nGamesReleased  nAwardsRecvd  Award_Ratio
# platform      release_year
# Wireless      2004                     166            82     0.493976
# PlayStation 2 2003                     221            68     0.307692
# PlayStation 3 2011                     228            64     0.280702
# Xbox 360      2010                     248            63     0.254032
# ...

# %% [markdown]
# 2004 was the best year because in this highest editor reward ratio was given. wireless game achieve the highest award.

# %%
bar=df['editors_choice'].plot.bar(x=df['platform'],legend=False)
bar.set_ylabel('release_year')
# Out:
# Text(0, 0.5, 'release_year')

# %% [markdown]
# # Random Probality

# %%
Puzzle = df.groupby(df['genre']=='puzzle')

# %%
Puzzle
