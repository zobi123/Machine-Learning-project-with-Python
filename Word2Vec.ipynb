# %% [markdown]
# # Word2Vec model visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime
from pandas import Series
import warnings
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import os
import nltk
import re
from gensim.models import Word2Vec
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ZuBaiR\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # Dataset Import

# %%
data ='blog_nature.xlsx'
dataset = pd.read_excel(data)

# %%
dataset.head()
# Out:
#   article_date                                      article_title  \
# 0   2019-09-18  The story behind the story: The monster and th...
# 1   2019-09-18  Peer Review Week 2019: Improving peer review q...
# 2   2019-09-11           The story behind the story: Hello, Hello
# 3   2019-09-04       The story behind the story: What must remain
# 4   2019-09-03  Call for submissions: High-throughput 3D scree...
#
#                                      article_content  \
# 0  This week, Futures is delighted to welcome Dol...
# 1  This guest blog comes from Sowmya Swaminathan,...
# 2  In this week‚Äôs Futures Jeff Hecht puts us in...
# 3  In this week‚Äôs Futures, Thomas Broderick tak...
# 4  Call for Submissions\nHigh-throughput 3D Scree...
#
#                                          article_url
# 0  http://blogs.nature.com/futureconditional/2019...
# 1  http://blogs.nature.com/ofschemesandmemes/2019...
# 2  http://blogs.nature.com/futureconditional/2019...
# 3  http://blogs.nature.com/futureconditional/2019...
# 4  http://blogs.nature.com/scientificdata/2019/09...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822 entries, 0 to 821
# Data columns (total 4 columns):
# article_date       822 non-null datetime64[ns]
# article_title      822 non-null object
# article_content    822 non-null object
# article_url        822 non-null object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 25.8+ KB

# %%
dataset.describe()
# Out:
#                article_date                     article_title  \
# count                   822                               822
# unique                  453                               750
# top     2017-12-20 00:00:00  Ageism in academic jobs in India
# freq                      8                                 3
# first   2016-12-07 00:00:00                               NaN
# last    2019-09-18 00:00:00                               NaN
#
#                                           article_content  \
# count                                                 822
# unique                                                753
# top     Now open for submissions, Nature Machine Intel...
# freq                                                    2
# first                                                 NaN
# last                                                  NaN
#
#                                               article_url
# count                                                 822
# unique                                                753
# top     http://blogs.nature.com/houseofwisdom/2017/04/...
# freq                                                    2
# first                                                 NaN
# last                                                  NaN

# %%
dataset.describe(include=['O'])
# Out:
#                            article_title  \
# count                                822
# unique                               750
# top     Ageism in academic jobs in India
# freq                                   3
#
#                                           article_content  \
# count                                                 822
# unique                                                753
# top     Now open for submissions, Nature Machine Intel...
# freq                                                    2
#
#                                               article_url
# count                                                 822
# unique                                                753
# top     http://blogs.nature.com/houseofwisdom/2017/04/...
# freq                                                    2

# %%
article_content=[]

# %%
article_content=dataset['article_content']

# %%
article_content
# Out:
# 0      This week, Futures is delighted to welcome Dol...
# 1      This guest blog comes from Sowmya Swaminathan,...
# 2      In this week‚Äôs Futures Jeff Hecht puts us in...
# 3      In this week‚Äôs Futures, Thomas Broderick tak...
# 4      Call for Submissions\nHigh-throughput 3D Scree...
#                              ...
# 817    Enterprising early career researchers get some...
# 818    This week, Futures welcomes Laurence Raphael B...
# 819    Steffen Schulz was completing his PhD in medic...
# 820    Meta-analysis is common in clinical research, ...
# 821    The New Year is around the corner, and so it‚Ä...
# Name: article_content, Length: 822, dtype: object

# %%
for text in article_content:
    text = re.sub(r"^https://t.co/[a-zA-Z0-9]*\s", " ", text)
    text = re.sub(r"\s+https://t.co/[a-zA-Z0-9]*\s", " ", text)
    text = re.sub(r"\s+https://t.co/[a-zA-Z0-9]*$", " ", text)
    text = tweet.lower()
    text = re.sub(r"that's","that is",text)
    text = re.sub(r"there's","there is",text)
    text = re.sub(r"what's","what is",text)
    text = re.sub(r"where's","where is",text)
    text = re.sub(r"it's","it is",text)
    text = re.sub(r"who's","who is",text)
    text = re.sub(r"i'm","i am",text)
    text = re.sub(r"she's","she is",text)
    text = re.sub(r"he's","he is",text)
    text = re.sub(r"they're","they are",text)
    text = re.sub(r"who're","who are",text)
    text = re.sub(r"ain't","am not",text)
    text = re.sub(r"wouldn't","would not",text)
    text = re.sub(r"shouldn't","should not",text)
    text = re.sub(r"can't","can not",text)
    text = re.sub(r"couldn't","could not",text)
    text = re.sub(r"won't","will not",text)
    text = re.sub(r"\W"," ",text)
    text = re.sub(r"\d"," ",text)
    text = re.sub(r"\s+[a-z]\s+"," ",text)
    text = re.sub(r"\s+[a-z]$"," ",text)
    text = re.sub(r"^[a-z]\s+"," ",text)
    text = re.sub(r"\s+"," ",text)

# %%
# Preparing the dataset
sentences = nltk.sent_tokenize(text)

sentences = [nltk.word_tokenize(sentence) for sentence in sentences]

for i in range(len(sentences)):
    sentences[i] = [word for word in sentences[i] if word not in stopwords.words('english')]

# %%
# Training the Word2Vec model
model = Word2Vec(sentences, min_count=1)

words = model.wv.vocab

words
# Out:
# {'new': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5c88>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5888>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5c08>,
#  'corner': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5cc8>,
#  'äôs': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5488>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5b08>,
#  'roll': <gensim.models.keyedvectors.Vocab at 0x1c2b55b59c8>,
#  'finalists': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5c48>,
#  'nature': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5ec8>,
#  'india': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5a48>,
#  'photo': <gensim.models.keyedvectors.Vocab at 0x1c2b55b56c8>,
#  'contest': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5408>,
#  'third': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5f08>,
#  'edition': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5d48>,
#  'usual': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5b48>,
#  'received': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5988>,
#  'fantastic': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5808>,
#  'response': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5688>,
#  'äî': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5d08>,
#  'hundreds': <gensim.models.keyedvectors.Vocab at 0x1c2b55b58c8>,
#  'entries': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5e08>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x1c2b55b55c8>,
#  'theme': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5b88>,
#  'simply': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5388>,
#  'äònature': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5f88>,
#  'äô': <gensim.models.keyedvectors.Vocab at 0x1c2b55b5a88>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x1c2ba2c1808>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x1c2ba2c1788>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x1c2ba2c1b08>,
#  'inherent': <gensim.models.keyedvectors.Vocab at 0x1c2ba2c1ac8>,
#  'connect': <gensim.models.keyedvectors.Vocab at 0x1c2ba2c1ec8>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x1c2ba2c1f88>,
#  'element': <gensim.models.keyedvectors.Vocab at 0x1c2ba2c1988>,
#  'photos': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e1708>,
#  'merrier': <gensim.models.keyedvectors.Vocab at 0x1c2b81a6ec8>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e7208>,
#  'novelty': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e73c8>,
#  'beyond': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e7648>,
#  'expectation': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e7d88>,
#  'pictures': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e7708>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e7608>,
#  'pieces': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e7888>,
#  'art': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e7b08>,
#  'mix': <gensim.models.keyedvectors.Vocab at 0x1c2b9f87fc8>,
#  'amateur': <gensim.models.keyedvectors.Vocab at 0x1c2b4958ec8>,
#  'professional': <gensim.models.keyedvectors.Vocab at 0x1c2b4943f08>,
#  'photographers': <gensim.models.keyedvectors.Vocab at 0x1c2b55b73c8>,
#  'scientists': <gensim.models.keyedvectors.Vocab at 0x1c2b55b7588>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x1c2b55b7948>,
#  'mobile': <gensim.models.keyedvectors.Vocab at 0x1c2b55b75c8>,
#  'cameras': <gensim.models.keyedvectors.Vocab at 0x1c2b55b7348>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x1c2b55b7b88>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x1c2b55b7408>,
#  'dslrs': <gensim.models.keyedvectors.Vocab at 0x1c2b55b7cc8>,
#  'vying': <gensim.models.keyedvectors.Vocab at 0x1c2b55b7988>,
#  'spot': <gensim.models.keyedvectors.Vocab at 0x1c2b55b7bc8>,
#  'capture': <gensim.models.keyedvectors.Vocab at 0x1c2b55b7808>,
#  'tough': <gensim.models.keyedvectors.Vocab at 0x1c2b55b7a88>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x1c2b55b7708>,
#  'editorial': <gensim.models.keyedvectors.Vocab at 0x1c2b55b7188>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x1c2b55b7288>,
#  'team': <gensim.models.keyedvectors.Vocab at 0x1c2b55b7b08>,
#  'selecting': <gensim.models.keyedvectors.Vocab at 0x1c2b246c8c8>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x1c2b243d848>,
#  'winners': <gensim.models.keyedvectors.Vocab at 0x1c2b88a7388>,
#  'stand': <gensim.models.keyedvectors.Vocab at 0x1c2b494d148>,
#  'chance': <gensim.models.keyedvectors.Vocab at 0x1c2b494d108>,
#  'seeing': <gensim.models.keyedvectors.Vocab at 0x1c2b494df48>,
#  'grace': <gensim.models.keyedvectors.Vocab at 0x1c2b494d0c8>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e0a08>,
#  'page': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e0bc8>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e0c88>,
#  'forthcoming': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e0b88>,
#  'print': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e0108>,
#  'publications': <gensim.models.keyedvectors.Vocab at 0x1c2b48fd788>,
#  'winner': <gensim.models.keyedvectors.Vocab at 0x1c2b48fd348>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x1c2b48fdc08>,
#  'runners': <gensim.models.keyedvectors.Vocab at 0x1c2b48fd1c8>,
#  'receive': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e8188>,
#  'copy': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e8088>,
#  'latest': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e8288>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e85c8>,
#  'annual': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e8348>,
#  'volume': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e8908>,
#  'enviable': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e87c8>,
#  'bag': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e8948>,
#  'goodies': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e8bc8>,
#  'springer': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e8a08>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e8a48>,
#  'final': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e8a88>,
#  'announcement': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e8888>,
#  'rolling': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e8dc8>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x1c2ba2e8c88>,
#  'competition': <gensim.models.keyedvectors.Vocab at 0x1c2b81affc8>,
#  'particular': <gensim.models.keyedvectors.Vocab at 0x1c2b245b808>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x1c2b4903148>,
#  'merit': <gensim.models.keyedvectors.Vocab at 0x1c2b85bae48>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x1c2b4905388>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x1c2b4905308>,
#  'indigenus': <gensim.models.keyedvectors.Vocab at 0x1c2b48fe288>,
#  'blog': <gensim.models.keyedvectors.Vocab at 0x1c2b48fe108>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x1c2b48fe688>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x1c2b48feb88>,
#  'media': <gensim.models.keyedvectors.Vocab at 0x1c2b48feb08>,
#  'platforms': <gensim.models.keyedvectors.Vocab at 0x1c2b48fe048>,
#  'twitter': <gensim.models.keyedvectors.Vocab at 0x1c2b4921548>,
#  'facebook': <gensim.models.keyedvectors.Vocab at 0x1c2b49215c8>,
#  'results': <gensim.models.keyedvectors.Vocab at 0x1c2b4921448>,
#  'announced': <gensim.models.keyedvectors.Vocab at 0x1c2b4921fc8>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x1c2b4921a88>,
#  'december': <gensim.models.keyedvectors.Vocab at 0x1c2b4921088>,
#  'brace': <gensim.models.keyedvectors.Vocab at 0x1c2b4921408>,
#  'announce': <gensim.models.keyedvectors.Vocab at 0x1c2b4868f48>,
#  'finalist': <gensim.models.keyedvectors.Vocab at 0x1c2b4868dc8>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x1c2b4868bc8>,
#  'ravi': <gensim.models.keyedvectors.Vocab at 0x1c2b4868c08>,
#  'hegde': <gensim.models.keyedvectors.Vocab at 0x1c2b4868c48>,
#  'bengaluru': <gensim.models.keyedvectors.Vocab at 0x1c2b48688c8>,
#  'caption': <gensim.models.keyedvectors.Vocab at 0x1c2b4868988>,
#  'äòbubbling': <gensim.models.keyedvectors.Vocab at 0x1c2b4868e08>,
#  'moments': <gensim.models.keyedvectors.Vocab at 0x1c2b4868f88>,
#  'works': <gensim.models.keyedvectors.Vocab at 0x1c2b4941588>,
#  'department': <gensim.models.keyedvectors.Vocab at 0x1c2b49416c8>,
#  'psychopharmacology': <gensim.models.keyedvectors.Vocab at 0x1c2b49417c8>,
#  'national': <gensim.models.keyedvectors.Vocab at 0x1c2b4941e88>,
#  'institute': <gensim.models.keyedvectors.Vocab at 0x1c2b4941e08>,
#  'mental': <gensim.models.keyedvectors.Vocab at 0x1c2b49412c8>,
#  'health': <gensim.models.keyedvectors.Vocab at 0x1c2b4941148>,
#  'neuro': <gensim.models.keyedvectors.Vocab at 0x1c2b4941c88>,
#  'sciences': <gensim.models.keyedvectors.Vocab at 0x1c2b4941408>,
#  'nimhans': <gensim.models.keyedvectors.Vocab at 0x1c2b4941cc8>,
#  'describes': <gensim.models.keyedvectors.Vocab at 0x1c2b4941248>,
#  'thus': <gensim.models.keyedvectors.Vocab at 0x1c2b49413c8>,
#  'äúthis': <gensim.models.keyedvectors.Vocab at 0x1c2b49410c8>,
#  'memorable': <gensim.models.keyedvectors.Vocab at 0x1c2b4941d88>,
#  'photographs': <gensim.models.keyedvectors.Vocab at 0x1c2b4941b08>,
#  'shot': <gensim.models.keyedvectors.Vocab at 0x1c2b4941448>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x1c2b4941108>,
#  'fortunate': <gensim.models.keyedvectors.Vocab at 0x1c2b49414c8>,
#  'exciting': <gensim.models.keyedvectors.Vocab at 0x1c2b491e7c8>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x1c2b491ed88>,
#  'incredible': <gensim.models.keyedvectors.Vocab at 0x1c2b491e948>,
#  'sand': <gensim.models.keyedvectors.Vocab at 0x1c2b491e9c8>,
#  'bubbler': <gensim.models.keyedvectors.Vocab at 0x1c2b491e808>,
#  'actively': <gensim.models.keyedvectors.Vocab at 0x1c2b491e308>,
#  'engaged': <gensim.models.keyedvectors.Vocab at 0x1c2b491e848>,
#  'feeding': <gensim.models.keyedvectors.Vocab at 0x1c2b491ec08>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x1c2b491e5c8>,
#  'tiny': <gensim.models.keyedvectors.Vocab at 0x1c2b491ea08>,
#  'balls': <gensim.models.keyedvectors.Vocab at 0x1c2b4901508>,
#  'lied': <gensim.models.keyedvectors.Vocab at 0x1c2b486b7c8>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x1c2b486b748>,
#  'wetting': <gensim.models.keyedvectors.Vocab at 0x1c2b486b808>,
#  'clothes': <gensim.models.keyedvectors.Vocab at 0x1c2b48ce208>,
#  'seawater': <gensim.models.keyedvectors.Vocab at 0x1c2b48ce808>,
#  'rare': <gensim.models.keyedvectors.Vocab at 0x1c2b48cecc8>,
#  'tosses': <gensim.models.keyedvectors.Vocab at 0x1c2b48ce6c8>,
#  'bubble': <gensim.models.keyedvectors.Vocab at 0x1c2b48ce188>,
#  'fraction': <gensim.models.keyedvectors.Vocab at 0x1c2b48ce0c8>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x1c2b48ce408>,
#  'bubblers': <gensim.models.keyedvectors.Vocab at 0x1c2b48ccdc8>,
#  'sieve': <gensim.models.keyedvectors.Vocab at 0x1c2b48ccbc8>,
#  'micro': <gensim.models.keyedvectors.Vocab at 0x1c2b48ccb48>,
#  'nutrients': <gensim.models.keyedvectors.Vocab at 0x1c2b48cce08>,
#  'grains': <gensim.models.keyedvectors.Vocab at 0x1c2b48ccd08>,
#  'feed': <gensim.models.keyedvectors.Vocab at 0x1c2b482be88>,
#  'repack': <gensim.models.keyedvectors.Vocab at 0x1c2b482bec8>,
#  'unwanted': <gensim.models.keyedvectors.Vocab at 0x1c2b48fc808>,
#  'particles': <gensim.models.keyedvectors.Vocab at 0x1c2b48fc6c8>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x1c2b48fc388>,
#  'generally': <gensim.models.keyedvectors.Vocab at 0x1c2b48fc248>,
#  'mm': <gensim.models.keyedvectors.Vocab at 0x1c2b48fcec8>,
#  'diameter': <gensim.models.keyedvectors.Vocab at 0x1c2b48fc308>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x1c2b48fcbc8>,
#  'tides': <gensim.models.keyedvectors.Vocab at 0x1c2b9f8fa08>,
#  'intense': <gensim.models.keyedvectors.Vocab at 0x1c2b9f8f708>,
#  'activity': <gensim.models.keyedvectors.Vocab at 0x1c2b9f8f288>,
#  'creatures': <gensim.models.keyedvectors.Vocab at 0x1c2ba2bbb88>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x1c2b4950cc8>,
#  'beautiful': <gensim.models.keyedvectors.Vocab at 0x1c2b4950848>,
#  'intricate': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f0f48>,
#  'patterns': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f0048>,
#  'seashore': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f0288>,
#  'äù': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f0148>,
#  'photograph': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f0108>,
#  'taken': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f0488>,
#  'dhareshwara': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f0508>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f0548>,
#  'honavar': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f0448>,
#  'uttara': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f0348>,
#  'kannada': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f03c8>,
#  'district': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f00c8>,
#  'karnataka': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f0948>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f0848>,
#  'congratulations': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f0388>,
#  'decision': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f0788>,
#  'chose': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f0748>,
#  'partly': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f0b08>,
#  'influenced': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f0908>,
#  'engagement': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f0988>,
#  'reception': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f0ac8>,
#  'receives': <gensim.models.keyedvectors.Vocab at 0x1c2ba2f0188>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x1c2ba2fd348>,
#  'fair': <gensim.models.keyedvectors.Vocab at 0x1c2ba2fd388>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x1c2ba2fde08>,
#  'consideration': <gensim.models.keyedvectors.Vocab at 0x1c2ba2fdfc8>,
#  'picture': <gensim.models.keyedvectors.Vocab at 0x1c2ba2fd448>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x1c2b4908108>,
#  'seven': <gensim.models.keyedvectors.Vocab at 0x1c2b491cd88>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x1c2b491cc48>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x1c2b491c848>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x1c2b4946d48>,
#  'promote': <gensim.models.keyedvectors.Vocab at 0x1c2b4946bc8>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x1c2b4946c88>,
#  'favourite': <gensim.models.keyedvectors.Vocab at 0x1c2b4946948>,
#  'hashtag': <gensim.models.keyedvectors.Vocab at 0x1c2b4946a48>,
#  'natureindphoto': <gensim.models.keyedvectors.Vocab at 0x1c2b4946a88>}

# %%
# Finding Word Vectors
vector = model.wv['india']

# %%
vector
# Out:
# array([-3.5887011e-03, -1.6784341e-03,  4.5566871e-03, -5.0222338e-04,
#        -7.3279196e-05,  2.3306727e-03,  1.5848598e-03,  8.3108275e-04,
#         9.4008999e-04,  1.1550441e-03,  3.9417553e-03, -3.7342712e-04,
#         2.8956446e-03,  3.9245007e-03, -2.5665448e-03,  2.1828590e-04,
#        -9.4088359e-04, -4.6922304e-03,  2.4502531e-03, -4.1211601e-03,
#         1.3233366e-03,  2.8108547e-03, -3.9333496e-03, -4.2456272e-03,
#         2.5732245e-04,  3.4565551e-03,  3.3393169e-03, -2.6141426e-03,
#         4.3536057e-03, -4.4467417e-03, -1.0138045e-03,  4.1912924e-03,
#        -2.2287380e-03,  3.2256027e-03, -2.6507946e-03,  2.6267366e-03,
#         1.5610363e-03,  4.8480728e-03,  3.5254720e-03, -3.5698963e-03,
#        -2.7748428e-03,  4.8003267e-03,  7.2121402e-05, -4.7613750e-03,
#         1.7634080e-03,  4.7058943e-03,  5.6458439e-04,  4.9308588e-04,
#        -4.1148933e-03, -3.8271993e-03, -4.2646839e-03, -4.6498412e-03,
#        -3.7665090e-03, -1.6072104e-03,  2.2332738e-04,  2.5417781e-03,
#        -3.6744864e-04, -2.4072977e-03,  2.0596243e-03,  3.7352312e-03,
#        -4.1756108e-03,  3.3933250e-03, -2.5653031e-03, -3.8015256e-03,
#        -5.3958164e-04, -1.0979008e-03, -4.7463067e-03,  4.8107929e-03,
#         4.6500485e-04, -4.4678422e-03,  6.3662312e-04,  3.3859098e-03,
#        -4.9995212e-03, -2.1341811e-03, -4.0319566e-05,  3.0287288e-03,
#         1.7278633e-04,  3.8102337e-03,  2.9203154e-03, -7.8000757e-04,
#        -2.2079009e-03, -8.2222786e-04,  1.1547788e-03,  1.8375786e-03,
#        -2.6597029e-03,  5.0537353e-03,  4.0662835e-05,  1.0551969e-03,
#        -4.1209958e-03, -1.3366805e-03, -3.1706055e-03,  4.5937966e-03,
#        -2.3893714e-03,  3.3653923e-03, -2.9372154e-03,  4.7102929e-03,
#        -1.1390784e-03, -4.3115648e-03, -2.7287484e-03, -1.7606558e-03],
#       dtype=float32)

# %%
# Most similar words
similar = model.wv.most_similar('india')

# %%
similar
# Out:
# [('usual', 0.2780580520629883),
#  ('pieces', 0.2767114043235779),
#  ('cameras', 0.26401814818382263),
#  ('congratulations', 0.26179933547973633),
#  ('grains', 0.2495436668395996),
#  ('feed', 0.24940896034240723),
#  ('forthcoming', 0.24386201798915863),
#  ('volume', 0.2396804392337799),
#  ('year', 0.2151029258966446),
#  ('top', 0.2105443775653839)]

# %%
import wordcloud
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                text = text, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-0092c322adf9> in <module>
#       1 import wordcloud
# ----> 2 wordcloud = WordCloud(width = 800, height = 800,
#       3                 background_color ='white',
#       4                 text = text,
#       5                 min_font_size = 10).generate(comment_words)
#
# NameError: name 'WordCloud' is not defined
